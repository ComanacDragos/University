# %%
import Plots, DataFrames, CSV
import Statistics
print("done")
# Out:
# done

# %% [markdown]
# Problem book
# 1

# %%
# a)

x0 = [1.5, 2]
x1 = [3, 1]

line = λ -> x0 + λ*(x1-x0)

@show line(5)

Plots.scatter(
    [x0[1], x1[1]],[x0[2], x1[2]],
    size=(360,180),label=false
)
# Out:
# line(5) = [9.0, -3.0]
